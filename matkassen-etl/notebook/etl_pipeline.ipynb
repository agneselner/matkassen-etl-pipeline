# %%
print("Jupyter funkar 🎉")
# Out:
# Jupyter funkar 🎉

# %%
import pandas as pd
print("pandas funkar 🎉")
# Out:
# pandas funkar 🎉

# %%
import os
os.getcwd()
# Out:
# '/Users/kiara/Documents/matkassen-etl/notebook'

# %%
import pandas as pd

# Läs in huvuddatan (filen ligger i samma mapp som notebook)
df = pd.read_csv("matkassen_data.csv")

# Visa de första 5 raderna
df.head()
# Out:
#        leverans_id prenumeration_id     kund_id pren_startdatum paus_från  \
# 0  LEV-2024-000001        PREN-1002  KUND-05001      2024-04-10       NaN
# 1  LEV-2024-000002        PREN-1003  KUND-05002      2024-06-12       NaN
# 2  LEV-2024-000003        PREN-1011  KUND-05010      2024-05-11       NaN
# 3  LEV-2024-000004        PREN-1017  KUND-05016      2024-05-26       NaN
# 4  LEV-2024-000005        PREN-1018  KUND-05017      2024-05-02       NaN
#
#   paus_till pren_avslutsdatum        kasstyp kostpreferens antal_portioner  \
# 0       NaN               NaN       Klassisk      Standard               4
# 1       NaN               NaN         Familj      Standard               6
# 2       NaN        2024-07-16     Vegetarisk           NaN               4
# 3       NaN               NaN  Snabb & Enkel     Laktosfri               4
# 4       NaN        2024-08-19       KLASSISK           NaN               2
#
#    ... leveransdatum postnummer veckapris leveransstatus  \
# 0  ...    2024-07-03      10393       699      Levererad
# 1  ...    2024-07-02      40545    919,00      Levererad
# 2  ...    2024-07-02      10686       709      Levererad
# 3  ...    2024-07-01      40695       689      Levererad
# 4  ...    2024-07-01      21938       499      Levererad
#
#                        recept_1                   recept_2  \
# 0  Panerad fisk med remouladsås      Kyckling Tikka Masala
# 1        Chicken nuggets-sallad   Köttbullar med makaroner
# 2            Falafel med hummus               Svamprisotto
# 3               15-minuters wok  Toast med avokado och ägg
# 4  Panerad fisk med remouladsås     Laxfile med potatismos
#
#                     recept_3  \
# 0      Köttfärssås med pasta
# 1  Fiskpinnar med potatismos
# 2         Vegetarisk lasagne
# 3           Snabb tomatsoppa
# 4            Pasta Carbonara
#
#                                          omdöme_text omdömesdatum omdömesbetyg
# 0                                                NaN          NaN          NaN
# 1          Älskar att slippa planera middagar. Tack!   2024-07-07          4.0
# 2  Svamprisotto var verkligen inte gott. Slängde ...   2024-07-06          2.0
# 3         Priset är högt men sparar tid. På gränsen.   2024-07-06          3.0
# 4      Fungerar, men recepten börjar bli repetitiva.   2024-07-08          3.0
#
# [5 rows x 21 columns]
